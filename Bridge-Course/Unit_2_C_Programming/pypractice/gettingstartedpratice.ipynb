# %%
import pandas as pd

# %%
a = 2 
print(type(a))
# Out:
# <class 'int'>

# %%
a = 12
b = 10
print("what is the product of a and b ")
print(a * b)
# Out:
# what is the product of a and b
# 120

# %% [markdown]
# ###script mode in Jupyter Notebook

# %%
# !python --version
# Out:
# Python 3.13.2

# %%
# !python app.py
# Out:
# hello world
# who are you?

# %% [markdown]
# Dymanic types in python
#
# python as a script or langauge

# %%
a = 30

# %%
a = "akhand"

# %%
a[1]
# Out:
# 'i'

# %%
a[1] = "A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a[1] = "A"
#
# TypeError: 'str' object does not support item assignment

# %%
a = 20 
print(type(a))
a = 2/10
print(type(a))
a = "Text"
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
id("aasdasd")
# Out:
# 4462217664

# %%
print(i4462217664)
# Out:
#   Cell In[13], line 1
#     print(id(4462217664)
#                         ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# Inbuilt function need to be passed values.
# attribute get the arguments which it is connect to by deflut but some may beed additional arguments

# %%
print(type(10/5))
# Out:
# <class 'float'>

# %%
pwd
# Out:
# '/Users/alpha/Desktop/M.tech Martrial/bridge couse/UPES_PG_Template/Bridge-Course/pypractice'
