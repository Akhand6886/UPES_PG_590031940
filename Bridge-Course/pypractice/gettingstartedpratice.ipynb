# %%
import pandas as pd

# %%
a = 2 
print(type(a))
# Out:
# <class 'int'>

# %%
a = 12
b = 10
print("what is the product of a and b ")
print(a * b)
# Out:
# what is the product of a and b
# 120

# %% [markdown]
# ###script mode in Jupyter Notebook

# %%
# !python --version
# Out:
# Python 3.13.2
