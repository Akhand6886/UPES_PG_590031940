# %%
array = [3, 7, 2, 9, 1, 5]
largest = max(array)
print(largest)
# Out:
# 9

# %%
array = [3, 4, 5, 12, 12, 8, 9]

a = array[0]
index = 0
positionoflargest = 0

for i in range(len(array)):
    if array[i] > a:
        a = array[i]
        positionoflargest = i
    if array[i] == a and  index != 0:
        positionoflargest1 = i
        

print(a)
print(positionoflargest)
print(positionoflargest1)
# Out:
# 12
# 3
# 4

# %%
largest_value = array[0]
positions = [0]  
index = 0

for num in array:
    
    if num > largest_value:
        largest_value = num
        positions = [index]
    
    elif num == largest_value and index != 0:
        positions.append(index)
        
    index = index + 1

print(largest_value)
print(positions)
# Out:
# 12
# [3, 4]

# %%
array = ['rohiy', 'rohiz', 'dfg', 'acr', 'awe', 'fds', 'sdfsd']
array.sort()
print(array)
# Out:
# ['acr', 'awe', 'dfg', 'fds', 'rohiy', 'rohiz', 'sdfsd']

# %%
words = ['abc', 'bcd', 'b', 'cde', 'abcde']


for i in range(len(words)):

    for j in range(0, len(words) - i - 1):

        if words[j] > words[j + 1]:

            words[j], words[j + 1] = words[j + 1], words[j]
            swapped = True

print(words)
# Out:
# ['abc', 'abcde', 'b', 'bcd', 'cde']

# %% [markdown]
# ## Chapter 3

# %%
import math
print(math.sqrt(64))

from math  import sqrt
print(int(sqrt(64)))

import math as m 

print(m.pi)
# Out:
# 8.0
# 8
# 3.141592653589793

# %%
import calc 
print(calc.sub(10, 5))
# Out:
# 5

# %% [markdown]
# ## Diffrent import styles

# %%
import calc 
from calc import add
from calc import add , sub
import calc as calc

# %% [markdown]
# ### 3) __name__ == "__main__" (very important)

# %%
def test():
    print("Testing Module...")

if __name__ == "__main__":
    test()
# Out:
# Testing Module...

# %% [markdown]
# __name__ == "__main__":
# it acts as a gatekeeper so that the code run only when called or directly run not when its imported in the another code

# %% [markdown]
# ### module search Path(sys.path)
#
# python searches moudles in :
#
# - curent folder
# - installed libraries
# - paths in sys.path

# %%
import sys
print(sys.path)
# Out:
# ['/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python313.zip', '/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13', '/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload', '', '/Users/alpha/Desktop/M.tech Martrial/bridge couse/UPES_PG_Template/pyenv/lib/python3.13/site-packages']

# %% [markdown]
# ### 5 ) Good pratices
#
# - keep module names lowercase
# - Avoid naming a file math.py or re.py ( conlifcts when import as a package or module)
# - keep resuable logic in modules , not in main .py

# %% [markdown]
# #creating Package , Folder structure __ init__.py , package usage
#
# 1) Basic package structure
#
# # folder stucture ( expected )
#
# you should have something like :
# ```
#  project_root/
#     main.py
#     dummyclac/
#     __init__.py
#     basic.py
#     advance.py
#     report.py
#     system_tools.py
# ```
#
# run command from **project_root** (important).
# ---
#
# ### 1) Example A - Import the package and use function directly
#
# created 'main.py' in 'project_root' :

# %%
import calc as cl

# %%
cl.add
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cl.add
#
# NameError: name 'cl' is not defined

# %%
from dummycalc import *
cl.basic.add(5,7)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from dummycalc import *
#       2 cl.basic.add(5,7)
#
# ModuleNotFoundError: No module named 'dummycalc'

# %%
import dummycalc as dc

print("add:", dc.add(10,20))
print("sub:" , dc.sub(20,10))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import dummycalc as dc
#       2
#       3 print("add:", dc.add(10,20))
#       4 print("sub:" , dc.sub(20,10))
#
# ModuleNotFoundError: No module named 'dummycalc'
