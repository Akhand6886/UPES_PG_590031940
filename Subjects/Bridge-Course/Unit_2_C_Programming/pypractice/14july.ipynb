# %%
array = [3, 7, 2, 9, 1, 5]
largest = max(array)
print(largest)
# Out:
# 9

# %%
array = [3, 4, 5, 12, 12, 8, 9]

a = array[0]
index = 0
positionoflargest = 0

for i in range(len(array)):
    if array[i] > a:
        a = array[i]
        positionoflargest = i
    elif array[i] == a and  index != 0:
        positionoflargest1 = i
        print(positionoflargest1)

print(a)
print(positionoflargest)
# Out:
# 12
# 3

# %%
largest_value = array[0]
positions = [0]  
index = 0

for num in array:
    
    if num > largest_value:
        largest_value = num
        positions = [index]
    
    elif num == largest_value and index != 0:
        positions.append(index)
        
    index = index + 1

print(largest_value)
print(positions)
# Out:
# 12
# [3, 4]

# %%
array = ['abc', 'dbs', 'dfg', 'acr', 'awe', 'fds', 'sdfsd']
array.sort()
print(array)
# Out:
# ['abc', 'acr', 'awe', 'dbs', 'dfg', 'fds', 'sdfsd']
