# %% [markdown]
# ### Unit IV

# %%
f = open("demo.txt", "w", encoding = "utf-8")
f.write("This is a demo file for testing purpose.\n")
f.write("This is the second line of the demo file.\n")
f.close()

# %%
# Out:
# This is a demo file for testing purpose.
# This is the second line of the demo file.

# %%
f = open("demo.txt", "w", encoding="utf-8")
f.write("this is a test write for demo.txt file\n")
f.close()

# %%
f = open("demo.txt", "r", encoding = "utf-8")
print(f.read())
f.close()
# Out:
# this is a test write for demo.txt file

# %%
with open("students.txt", "w+", encoding = "utf-8") as f :
    f.write("ABCDE")
    print("Pointer:", f.tell())
    f.seek(0)
    print("Read:", f.read(2))
# Out:
# Pointer: 5
# Read: AB
