# %% [markdown]
# ## Question 1
# Install Python and understand the difference between scripting mode and interactive mode in IDLE.
#
# **Interactive mode:** runs one statement at a time, auto-displays the result of the last expression (like this notebook's cells).
# **Scripting mode:** runs a saved `.py` file top to bottom; nothing auto-displays — you need `print()`.

# %%
import sys
print("Python is installed.")
print("Version:", sys.version)
