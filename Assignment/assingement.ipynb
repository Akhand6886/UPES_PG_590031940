# %% [markdown]
# <span style="color:white; background-color:#2E8B57; padding:2px 6px; border-radius:4px;"> ## Question 1
# Install Python and understand the difference between scripting mode and interactive mode in IDLE.
# </span>
#
# <span style="color:green">**Interactive mode:** runs one statement at a time, auto-displays the result of the last expression (like this notebook's cells).</span>
#
#
# <span style="color:#1E90FF">**Scripting mode:** runs a saved `.py` file top to bottom; nothing auto-displays — you need `print()`.</span>

# %% [markdown]
# the system check, works as-is

# %%
import sys
print("Python is installed.")
print("Version:", sys.version)
# Out:
# Python is installed.
# Version: 3.13.2 (main, Feb  4 2025, 14:51:09) [Clang 16.0.0 (clang-1600.0.26.6)]

# %% [markdown]
# demonstrate the "auto-echo" behavior Jupyter shares with IDLE's interactive mode:

# %%
name = "Python"
name          # no print() — Jupyter still shows this, just like IDLE's >>>
# Out:
# 'Python'

# %% [markdown]
# contrast with what scripting mode requires:

# %%
print(name)
# Out:
# Python

# %% [markdown]
# note the honest caveat

# %%
l = [1, 2, 3]
b = ['a', 'b', 'c']  
for _ in zip(l, b):
    print(_)
# Out:
# (1, 'a')
# (2, 'b')
# (3, 'c')

# %% [markdown]
# if we iterate

# %% [markdown]
# for each in (d.keys()

# %%
d = {'a': 1, 'b': 2, 'c': 3}
for each in (d.keys(), d.values()):
    print(each)
# Out:
# dict_keys(['a', 'b', 'c'])
# dict_values([1, 2, 3])

# %%
for each in d.keys():
    print(each)
# Out:
# a
# b
# c
